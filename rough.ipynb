# %%
inputs = ["Allan","Ojuka","computer science","october 2025"]

any(i.replace(" ","") == "Allan" for i in inputs)

# %%
# question 1
name = "John"
single= False

#Question 2
age = input("Please enter your age: ")

#Question 3
print("My name is John")
print("My age is 22")

#Question 4
name = "Tom"
single = True

#Question 5
print(name)

#Question 6
print(f"Hi my name is {name} I am {age} years old")
# Out:
# My name is John
# My age is 22
# Tom
# Hi my name is Tom I am 25 years old
