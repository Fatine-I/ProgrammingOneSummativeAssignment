# %%
PRODUCT_COLUMNS = [
        "product_id", "product_name", "category","brand",  "size", "supplier",
        "price", "quantity","entry_date","expiry_date"
]
PRODUCT_COLUMNS[0]
# Out:
# 'product_id'
